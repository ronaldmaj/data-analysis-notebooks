# %% [markdown]
# <a href="https://colab.research.google.com/github/ronaldmaj/data-analysis-notebooks/blob/master/POLA_Project_3_-_ML_Model_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # POLA Ship Detection Model 2 - Google Colab Notebook

# %% [markdown]
# In this notebook I will be looking at running an algoirthm to determine the presence of a container ship in an 80x80 sized image.
#
# This is in support of the project to identify container ships in the Port of Los Angeles (POLA) satellite images taken from the Planet (Planet Labs) servers for dates in 2018.
#
# This is the second notebook, which differs from the first in that a third category was added: partial_ship

# %%
import json, sys, random
import numpy as np
#! pip install tensorflow-gpu
# !pip3 install https://github.com/OlafenwaMoses/ImageAI/releases/download/2.0.2/imageai-2.0.2-py3-none-any.whl
# Out:
# ...
#     100% |████████████████████████████████| 153kB 277kB/s
# ...

# %%
from imageai.Prediction.Custom import ModelTraining

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls 'gdrive/My Drive/ships_sat2'
# Out:
# test  train

# %%
from tensorflow.python.client import device_lib

print("Show System RAM Memory:\n\n")
# !cat /proc/meminfo | egrep "MemTotal*"


print("\n\nShow Devices:\n\n"+str(device_lib.list_local_devices()))
# Out:
# Show System RAM Memory:
#
#
# MemTotal:       13335276 kB
#
#
# Show Devices:
#
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17950268474938058774
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 11502318898160791296
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 16644394556200441116
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11276946637
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 15841075885132152509
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %%
model_trainer = ModelTraining()
model_trainer.setModelTypeAsResNet()
model_trainer.setDataDirectory('gdrive/My Drive/ships_sat2')
model_trainer.trainModel(num_objects=3, num_experiments=20, enhance_data=True, batch_size=32, show_network_summary=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1 (BatchNo (None, 112, 112, 64) 256         conv2d[0][0]
# ...

# %% [markdown]
# Based on these results, we can see that the model is not very accurate.
#
# What we will do is increase the number of images by rotating, sharpening and increasing the brightness on the existing images in order to create "new" training and test material.
